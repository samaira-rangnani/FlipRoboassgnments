# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Grades.csv.crdownload')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
#We observe that only 1 column which is target variable has float datatype
#while others are object type i.e categorical columns

# %%
#As seat no holding only unique values id,not further used for analysis,hence dropping that column
df.drop('Seat No.',axis=1,inplace=True)

# %%
for i in df:
    print(i,"=", df[i].unique())
# Out:
# PH-121 = ['B-' 'A' 'D' 'A-' 'B+' 'B' 'C+' 'C' 'C-' 'D+' 'WU' 'A+' 'F']
# HS-101 = ['D+' 'D' 'B' 'C+' 'A-' 'B-' 'C-' 'B+' 'C' 'A' 'A+' 'F']
# CY-105 = ['C-' 'D+' 'A' 'A-' 'B' 'C+' 'B+' 'B-' 'C' 'D' nan 'WU' 'A+' 'F']
# HS-105/12 = ['C' 'D' 'B-' 'B+' 'D+' 'B' 'C-' 'C+' 'A-' 'A' nan 'WU' 'A+' 'F']
# MT-111 = ['C-' 'B-' 'B+' 'D' 'A' 'C+' 'A-' 'C' 'B' 'D+' nan 'A+' 'F' 'WU']
# CS-105 = ['D+' 'C' 'A' 'A-' 'B' 'B-' 'B+' 'C+' 'C-' 'A+' 'D']
# CS-106 = ['D' 'B-' 'D+' 'A-' 'C+' 'A' 'C-' 'C' 'B' 'B+' nan 'A+' 'F' 'WU']
# EL-102 = ['C-' 'A' 'B+' 'B' 'A-' 'B-' 'C' 'C+' 'D+' 'D' nan 'A+' 'WU' 'F']
# EE-119 = ['B-' 'D+' 'A-' 'D' 'A' 'B+' 'B' 'C-' 'C+' 'C' 'WU' nan 'A+']
# ME-107 = ['C-' 'D' 'A-' 'C+' 'B+' 'A' 'D+' 'C' 'B' 'B-' 'WU' nan 'F' 'A+']
# CS-107 = ['C-' 'B+' 'B-' 'D' 'C' 'A-' 'C+' 'D+' 'B' 'A' nan 'A+' 'I' 'WU' 'F']
# HS-205/20 = ['B+' 'C+' 'A-' 'B' 'A' 'B-' nan 'D' 'WU' 'A+' 'C' 'D+' 'C-' 'F']
# MT-222 = ['D' 'B-' 'A' 'D+' 'C' 'B+' 'A-' 'B' 'C+' nan 'C-' 'WU' 'F' 'A+' 'W']
# ...

# %%
#We observe that target variable holding  all unique values

# %%
df['CY-105'].nunique()
# Out:
# 13

# %%
#Checking no of unique values in each column
for i in df:
    print(i,"=",df[i].nunique())
# Out:
# PH-121 = 13
# HS-101 = 12
# CY-105 = 13
# HS-105/12 = 13
# MT-111 = 13
# CS-105 = 11
# CS-106 = 13
# EL-102 = 13
# EE-119 = 12
# ME-107 = 13
# CS-107 = 14
# HS-205/20 = 13
# MT-222 = 14
# EE-222 = 13
# MT-224 = 14
# CS-210 = 14
# CS-211 = 14
# CS-203 = 13
# CS-214 = 13
# EE-217 = 13
# CS-212 = 12
# CS-215 = 14
# MT-331 = 12
# EF-303 = 12
# HS-304 = 14
# CS-301 = 12
# CS-302 = 11
# TC-383 = 12
# MT-442 = 12
# EL-332 = 13
# CS-318 = 14
# CS-306 = 13
# CS-312 = 14
# CS-317 = 12
# CS-403 = 11
# CS-421 = 13
# CS-406 = 14
# CS-414 = 13
# CS-419 = 12
# CS-423 = 12
# CS-412 = 13
# CGPA = 491

# %%
#we observe that every column has unique values ranging from 11-14
#while CGPA i.e our target variable holds all continous and unique values,hence the problem is approached as Regression problem

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
#we observe that null values are present in data set
#Lets handle null values by imputation method
dfd = df.loc[~(df.isna().sum(axis=1)<=13)]
print(dfd)
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 44       D      C    NaN       NaN    NaN     C-    NaN    NaN     D+     WU
# 60       C     B+     WU        D+     C-     B-      F      D     A-      B
# 91      WU     C-      D         D     WU      D      D      D      C     D+
# 137     C-     C+     WU        WU     WU      B     WU     WU     A-     C+
# 142     C+     B-      B        A-      A     A-      C     WU     A-    NaN
# 143      D      D     WU        WU     WU      D     WU     WU      D     WU
# 281     WU     D+      F         F      F      D    NaN      D     WU      F
# 282     B-     C+     D+         D     A-     B-      B     B+    NaN      D
# 288      D     C-      D         C      D      D     B-      F     D+      F
# 565      F      F      D        C-    NaN     D+      D    NaN    NaN    NaN
#
#      ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# ...

# %%
j=dfd.index

# %%
#dropping the null values column holding null vlues<=13
df.drop(j,inplace=True)

# %%
df.shape
# Out:
# (561, 42)

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        0
# HS-105/12     0
# MT-111        0
# CS-105        0
# CS-106        0
# EL-102        0
# EE-119        0
# ME-107        0
# CS-107        0
# HS-205/20     0
# MT-222        0
# EE-222        0
# MT-224        0
# CS-210        0
# CS-211        0
# CS-203        0
# CS-214        0
# EE-217        0
# CS-212        0
# CS-215        0
# MT-331        0
# EF-303        0
# HS-304        0
# CS-301        0
# CS-302        0
# TC-383        0
# MT-442        0
# EL-332        0
# CS-318        0
# CS-306        0
# CS-312        1
# CS-317        2
# CS-403        3
# CS-421        2
# CS-406       75
# CS-414        3
# CS-419        3
# CS-423        4
# CS-412       69
# CGPA          0
# dtype: int64

# %%
#dropping null values from columns holding only 1,2,3 null values
df.dropna(subset=['CS-312','CS-317' ,    'CS-403',        'CS-421', 'CS-414',      'CS-419',        'CS-423'],inplace=True)

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        0
# HS-105/12     0
# MT-111        0
# CS-105        0
# CS-106        0
# EL-102        0
# EE-119        0
# ME-107        0
# CS-107        0
# HS-205/20     0
# MT-222        0
# EE-222        0
# MT-224        0
# CS-210        0
# CS-211        0
# CS-203        0
# CS-214        0
# EE-217        0
# CS-212        0
# CS-215        0
# MT-331        0
# EF-303        0
# HS-304        0
# CS-301        0
# CS-302        0
# TC-383        0
# MT-442        0
# EL-332        0
# CS-318        0
# CS-306        0
# CS-312        0
# CS-317        0
# CS-403        0
# CS-421        0
# CS-406       73
# CS-414        0
# CS-419        0
# CS-423        0
# CS-412       67
# CGPA          0
# dtype: int64

# %%
a=df['CS-406'].mode()
b=df['CS-412'].mode()
print(a)
print(b)
# Out:
# 0    A-
# Name: CS-406, dtype: object
# 0    A-
# Name: CS-412, dtype: object

# %%
df.loc[df['CS-406'].isnull().sum()]
# Out:
# PH-121          A
# HS-101         B-
# CY-105         B+
# HS-105/12      D+
# MT-111         D+
# CS-105         A-
# CS-106          D
# EL-102         B-
# EE-119         A-
# ME-107          A
# CS-107         C-
# HS-205/20       A
# MT-222          C
# EE-222         C+
# MT-224         C-
# CS-210         C-
# CS-211          D
# CS-203         C-
# CS-214         D+
# EE-217         C-
# CS-212          D
# CS-215          D
# MT-331         D+
# EF-303         C-
# HS-304         C+
# CS-301         B-
# CS-302         C+
# TC-383          D
# MT-442         B+
# EL-332          C
# CS-318         D+
# CS-306          C
# CS-312          C
# CS-317         C+
# CS-403          C
# CS-421         D+
# CS-406         B+
# CS-414         B+
# CS-419         C+
# CS-423         C+
# CS-412         A-
# CGPA         2.34
# Name: 73, dtype: object

# %%
#2 columns holding more null values ,hence replacing them with mode of values as we cannot drop such huge values
df['CS-406'].fillna("A-",inplace=True)

# %%
df['CS-412'].fillna("A-",inplace=True)

# %%
df.isnull().sum()
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
duplicate=df.duplicated()
print(duplicate.sum())
# Out:
# 0

# %%
#No duplicate values are present in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 557 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     557 non-null    object
#  1   HS-101     557 non-null    object
#  2   CY-105     557 non-null    object
#  3   HS-105/12  557 non-null    object
#  4   MT-111     557 non-null    object
#  5   CS-105     557 non-null    object
#  6   CS-106     557 non-null    object
#  7   EL-102     557 non-null    object
#  8   EE-119     557 non-null    object
#  9   ME-107     557 non-null    object
#  10  CS-107     557 non-null    object
#  11  HS-205/20  557 non-null    object
#  12  MT-222     557 non-null    object
#  13  EE-222     557 non-null    object
#  14  MT-224     557 non-null    object
#  15  CS-210     557 non-null    object
#  16  CS-211     557 non-null    object
#  17  CS-203     557 non-null    object
#  18  CS-214     557 non-null    object
# ...

# %%
df['CS-406'].value_counts()
# Out:
# A-    250
# A      79
# B+     63
# B      58
# B-     22
# C+     22
# C      19
# D+     14
# C-      8
# A+      8
# F       6
# D       5
# W       3
# Name: CS-406, dtype: int64

# %%
df['CS-412'].value_counts()
# Out:
# A-    224
# B+     80
# A      77
# B      65
# B-     37
# C+     24
# C      19
# C-      7
# D+      7
# F       6
# D       5
# A+      4
# W       2
# Name: CS-412, dtype: int64

# %%
#More  students achieved 'A-" grades in 4th year in CS subject

# %%
df['CS-214'].value_counts()
# Out:
# C     76
# A-    73
# B     62
# C-    57
# A     56
# B-    54
# D+    47
# C+    46
# B+    45
# D     29
# A+    12
# Name: CS-214, dtype: int64

# %%
#We observe that more students have obtaind "C" garde in subject Cs of 2nd year

# %%
df.describe(include="all")
# Out:
#        PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# count     557    557    557       557    557    557    557    557    557
# unique     11     11     11        11     11     11     11     11     11
# top        A-     A-      A         A     A-      A     A-     A-     A-
# freq      112     81    176        96    103    150    115    104    134
# mean      NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
# std       NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
# min       NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
# 25%       NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
# 50%       NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
# 75%       NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
# max       NaN    NaN    NaN       NaN    NaN    NaN    NaN    NaN    NaN
#
#        ME-107  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
#From aabove we observe tht unique values og grades present between 11 to 14
#we observe the frequency of grades and how many time that grade have been present in certain columns

# %%
#EDA===UNIVARIATE ANALYSIS

# %%
sns.countplot(x='CS-412',data=df)
# Out:
# <Axes: xlabel='CS-412', ylabel='count'>

# %%
#We observe that in 4th year the students of CS department have scored maxiumum A- grades following other grades

# %%
sns.countplot(x='HS-105/12',data=df)
# Out:
# <Axes: xlabel='HS-105/12', ylabel='count'>

# %%
#we observe that in 1st year HS department students have scored more of A grade foloowing other grades

# %%
sns.countplot(x='CS-312',data=df)
# Out:
# <Axes: xlabel='CS-312', ylabel='count'>

# %%
#We observe that students of 3rd year have scored more A grades following other grades in CS deaprtment

# %%
sns.countplot(x='CS-214',data=df)
# Out:
# <Axes: xlabel='CS-214', ylabel='count'>

# %%
#we observe that more students have scored C garde in 2nd year of CS deaprtment following up other grades

# %%
#lets see distribution of data in columns
plt.figure(figsize=(15,15))
p=1
for i in df:
    if p<=42:
        plt.subplot(11,4,p)
        sns.histplot(df[i],kde=True)
        plt.xlabel(i)
    p+=1
plt.tight_layout()

# %%
#From above graph w eobserve that columns MT ,CS-312 ,CS-406 ,CS-412 ,CS-414 are right skewed
#while other columns have uniformly skewed data

# %%
#BIVARIATE ANALYSIS

# %%
sns.barplot(x='CS-414',y='CGPA',data=df)
# Out:
# <Axes: xlabel='CS-414', ylabel='CGPA'>

# %%
#we observe that as gardes increases the CGPA acore increases

# %%
sns.barplot(x='CS-312',y='CGPA',data=df)
# Out:
# <Axes: xlabel='CS-312', ylabel='CGPA'>

# %%
#We observe that CGPA acore incraesing as the gardes increasein the 3rd year of CS department

# %%
sns.scatterplot(x='CS-414',y='CGPA',data=df)
# Out:
# <Axes: xlabel='CS-414', ylabel='CGPA'>

# %%
#we observe that cgpa lies between  3 to 4 for A+ grade
#while for A- grade cgpa lies bewtween 1 to 4
#students obtaining D grades have less cgpa score

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
sns.scatterplot(x='EE-119',y='CGPA',data=df)
# Out:
# <Axes: xlabel='EE-119', ylabel='CGPA'>

# %%
#we observe that cgpa lies between  3.5 to 4 for A+ grade
#while for A- grade cgpa lies bewtween 2 to 4
#students obtaining D grades have less cgpa score

# %%
sns.scatterplot(x='EL-332',y='CGPA',data=df)
# Out:
# <Axes: xlabel='EL-332', ylabel='CGPA'>

# %%
#we observe that cgpa lies between  3.5 to 4 for A+ grade
#while for A- grade cgpa lies bewtween 2 to 4
#students obtaining WU grades have lowest cgpa score

# %%
sns.scatterplot(x='CS-214',y='CGPA',data=df)
# Out:
# <Axes: xlabel='CS-214', ylabel='CGPA'>

# %%
#we observe that cgpa lies between  3.5 to 4 for A+ grade
#while for A- grade cgpa lies bewtween 2.5 to 4
#students obtaining D grades have lowest cgpa score

# %%
#Encoding Categorical Columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))
        
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 557 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     557 non-null    int32
#  1   HS-101     557 non-null    int32
#  2   CY-105     557 non-null    int32
#  3   HS-105/12  557 non-null    int32
#  4   MT-111     557 non-null    int32
#  5   CS-105     557 non-null    int32
#  6   CS-106     557 non-null    int32
#  7   EL-102     557 non-null    int32
#  8   EE-119     557 non-null    int32
#  9   ME-107     557 non-null    int32
#  10  CS-107     557 non-null    int32
#  11  HS-205/20  557 non-null    int32
#  12  MT-222     557 non-null    int32
#  13  EE-222     557 non-null    int32
#  14  MT-224     557 non-null    int32
#  15  CS-210     557 non-null    int32
#  16  CS-211     557 non-null    int32
#  17  CS-203     557 non-null    int32
#  18  CS-214     557 non-null    int32
#  19  EE-217     557 non-null    int32
# ...

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  557.000000  557.000000  557.000000  557.000000  557.000000  557.000000
# mean     3.675045    5.023339    2.770197    4.161580    3.825853    2.754039
# std      2.968717    2.772779    2.817783    3.145014    2.907478    2.629831
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    3.000000    0.000000    2.000000    2.000000    0.000000
# 50%      3.000000    5.000000    2.000000    4.000000    3.000000    2.000000
# 75%      6.000000    7.000000    4.000000    7.000000    6.000000    4.000000
# max     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  557.000000  557.000000  557.000000  557.000000  ...  557.000000
# mean     4.064632    3.867145    3.833034    4.696589  ...    4.077199
# ...

# %%
#checking correlation values
cor=df.corr()
cor
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.358818  0.534805   0.486449  0.450601  0.585024
# HS-101     0.358818  1.000000  0.314448   0.468366  0.423943  0.377671
# CY-105     0.534805  0.314448  1.000000   0.475048  0.513206  0.562002
# HS-105/12  0.486449  0.468366  0.475048   1.000000  0.476717  0.474522
# MT-111     0.450601  0.423943  0.513206   0.476717  1.000000  0.372157
# CS-105     0.585024  0.377671  0.562002   0.474522  0.372157  1.000000
# CS-106     0.276565  0.304225  0.348804   0.491281  0.488872  0.271322
# EL-102     0.401832  0.338941  0.416658   0.340736  0.537802  0.338143
# EE-119     0.575775  0.298862  0.475322   0.407119  0.396030  0.492923
# ME-107     0.521792  0.325988  0.454387   0.306892  0.457856  0.436049
# CS-107     0.464851  0.502811  0.442242   0.521846  0.465558  0.503633
# HS-205/20  0.288927  0.179015  0.234939   0.159708  0.319606  0.176867
# ...

# %%
#visualizing the correaltion values
plt.figure(figsize=(15,15))
sns.heatmap(cor,annot=True,linewidths=0.1)
# Out:
# <Axes: >

# %%
cor['CGPA'].sort_values(ascending=True)
# Out:
# CS-317      -0.801810
# CS-210      -0.792677
# EL-332      -0.792640
# CS-306      -0.770353
# CS-215      -0.758812
# CS-214      -0.754673
# CS-302      -0.754552
# MT-111      -0.743386
# MT-224      -0.729898
# CS-421      -0.729381
# CS-301      -0.727831
# CS-419      -0.723582
# EE-217      -0.680026
# MT-222      -0.675735
# CS-212      -0.665462
# CS-203      -0.659808
# TC-383      -0.657648
# ME-107      -0.657450
# EL-102      -0.653453
# CS-211      -0.649183
# EE-119      -0.645088
# CY-105      -0.638569
# PH-121      -0.638173
# CS-403      -0.634368
# CS-318      -0.628852
# MT-442      -0.628822
# CS-107      -0.622695
# HS-304      -0.621495
# HS-105/12   -0.614230
# EE-222      -0.609661
# CS-423      -0.594302
# CS-105      -0.577874
# MT-331      -0.575837
# EF-303      -0.544871
# CS-106      -0.544085
# CS-406      -0.541171
# CS-412      -0.531185
# HS-101      -0.526328
# CS-312      -0.523029
# HS-205/20   -0.464809
# CS-414      -0.457436
# ...

# %%
#Removing outliers
from scipy.stats import zscore
out=df[['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
       'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
       'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
       'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
       'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
       'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412']]
z=np.abs(zscore(out))
z
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0    0.446707  1.796441  1.857667   0.585076  1.436949  2.757771  1.847319
# 1    1.239036  1.435468  2.568083   1.539825  0.404200  1.235394  1.847319
# 2    1.239036  0.730371  0.983996   0.266827  0.059950  1.048172  0.350110
# 3    1.795302  0.713522  2.568083   1.539825  1.781199  0.286983  2.221621
# 4    0.564739  1.091344  0.273580   0.051423  1.317049  1.048172  0.772796
# ..        ...       ...       ...        ...       ...       ...       ...
# 566  0.227590  1.813291  0.983996   0.687922  0.972799  1.048172  0.772796
# 567  0.901888  1.813291  0.983996   1.324421  1.317049  1.048172  1.521400
# 568  0.227590  1.813291  0.273580   0.051423  1.317049  1.048172  1.521400
# 569  1.239036  0.369398  2.212875   1.324421  1.781199  2.757771  0.350110
# 570  0.783856  1.435468  2.212875   0.585076  0.748450  2.757771  0.398494
#
# ...

# %%
np.where(z>3)
# Out:
# (array([179, 191, 210, 256, 268, 305, 311, 329, 329, 329, 341, 341, 371,
#         376, 376, 399, 411, 412, 413, 413, 421, 435, 436, 436, 436, 442,
#         442, 443, 443, 447, 494, 497, 497, 501, 504, 504, 509, 509, 510,
#         510, 515, 537, 537, 539, 544, 547, 556], dtype=int64),
#  array([11, 11, 11, 11, 11, 11, 11, 24, 37, 40, 24, 37, 37, 37, 40, 37, 40,
#         37, 11, 37, 40, 36, 36, 37, 40, 36, 40, 36, 37, 40, 11, 36, 40, 40,
#         36, 40, 36, 40, 36, 40, 40, 37, 40, 40, 37, 37, 36], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (524, 42)

# %%
#we observe that almost 30 rows having outliers are been remove from dataframe
df=df_new

# %%
#Seperating independent and target variable
x=df.iloc[:,0:-1]
y=df['CGPA']

# %%
x.shape
# Out:
# (524, 41)

# %%
#Checking for VIF for confirming multicollinearity between columns
from statsmodels.stats.outliers_influence import variance_inflation_factor as vi
vif=pd.DataFrame()
vif['values']=[vi(x.values,i) for i in range(len(x.columns))]
vif['columns']=x.columns

# %%
vif.sort_values(by='values',ascending=True)
# Out:
#        values    columns
# 11   4.382698  HS-205/20
# 37   4.495101     CS-414
# 2    4.758444     CY-105
# 22   4.792664     MT-331
# 7    4.951930     EL-102
# 5    4.985379     CS-105
# 28   5.028995     MT-442
# 36   5.100740     CS-406
# 13   5.479059     EE-222
# 10   5.904691     CS-107
# 19   6.080474     EE-217
# 3    6.240899  HS-105/12
# 34   6.259041     CS-403
# 6    6.308265     CS-106
# 40   6.685986     CS-412
# 0    6.735200     PH-121
# 8    6.741992     EE-119
# 12   6.805575     MT-222
# 4    7.232193     MT-111
# 9    7.361389     ME-107
# 17   7.453174     CS-203
# 1    7.533695     HS-101
# 15   7.794932     CS-210
# 39   7.968960     CS-423
# 27   8.082244     TC-383
# 14   8.103178     MT-224
# 26   8.204281     CS-302
# 23   8.423883     EF-303
# 30   8.697969     CS-318
# 16   8.717692     CS-211
# 29   8.984306     EL-332
# 38   9.216225     CS-419
# 32   9.522841     CS-312
# 24   9.617025     HS-304
# 25   9.989933     CS-301
# 31  10.009064     CS-306
# ...

# %%
#As we observe that CY and MT column are high collinear dropping any 1 column
#As we observe that CS-214 and CS-306 column are high collinear dropping any 1 column
#As we observe that CS-317 and CS-412 column are high collinear dropping any 1 column
#As we observe that HS and EL column are high collinear dropping any 1 column
#CS-318 and CS-211 coolumns are highly collinear dropping any 1 column
#CS-312 and MT-224 columns are highly collinear dropping any 1 column
#CS-203 and TC-383 columns are highly collinear dropping any 1 column
#EE-119 and MT-222 columns are highly collinear dropping any 1 column
#HS-105/12 and CS-403 columns are highly collinear dropping any 1 column
#EL-102 and EE-222  columns are collinear dropping any 1 column
#MT-331 and CS-105 columns are collinear dropping any 1 column






x.drop('CY-105',axis=1,inplace=True)
x.drop('CS-214',axis=1,inplace=True)
x.drop('CS-421',axis=1,inplace=True)
x.drop('EL-332',axis=1,inplace=True)
x.drop('CS-318',axis=1,inplace=True)
x.drop('MT-224',axis=1,inplace=True)
x.drop('CS-203',axis=1,inplace=True)
x.drop('EE-119',axis=1,inplace=True)
x.drop('CS-403',axis=1,inplace=True)
x.drop('EE-222',axis=1,inplace=True)
x.drop('MT-331',axis=1,inplace=True)

# %%
x.shape
# Out:
# (524, 30)

# %%
#Checking once again for multicollinearity
vif=pd.DataFrame()
vif['values']=[vi(x.values,i) for i in range(len(x.columns))]
vif['columns']=x.columns
vif.sort_values(by='values',ascending=True)
# Out:
#        values    columns
# 9    4.201051  HS-205/20
# 26   4.208613     CS-414
# 4    4.400844     CS-105
# 25   4.554644     CS-406
# 21   4.736678     MT-442
# 6    4.784706     EL-102
# 13   5.514676     EE-217
# 8    5.518619     CS-107
# 2    5.862081  HS-105/12
# 0    6.058674     PH-121
# 29   6.118482     CS-412
# 5    6.240463     CS-106
# 10   6.522129     MT-222
# 3    6.645888     MT-111
# 7    6.724266     ME-107
# 1    6.993438     HS-101
# 11   7.128696     CS-210
# 20   7.597663     TC-383
# 28   7.705606     CS-423
# 12   7.842030     CS-211
# 16   7.858070     EF-303
# 19   7.912875     CS-302
# 17   8.352452     HS-304
# 27   8.564501     CS-419
# 23   8.603382     CS-312
# 15   8.869222     CS-215
# 18   8.975681     CS-301
# 22   9.554228     CS-306
# 14  10.703047     CS-212
# 24  11.955263     CS-317

# %%
#dropping Cs-317 columns as its highly collinear with other columns
x.drop('CS-317',axis=1,inplace=True)

# %%
x.shape
# Out:
# (524, 29)

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
x.shape
# Out:
# (524, 29)

# %%
x
# Out:
#      PH-121  HS-101  HS-105/12  MT-111  CS-105  CS-106  EL-102  ME-107  \
# 0         5      10          6       8      10       9       8       8
# 1         0       9          9       5       6       9       0       9
# 2         0       3          5       4       0       5       4       2
# 3         9       7          9       9       2      10       8       7
# 4         2       2          4       0       0       2       4       2
# ..      ...     ...        ...     ...     ...     ...     ...     ...
# 564       2       9          6       4       4       6       2       9
# 566       3       0          2       1       0       2       2       4
# 567       1       0          0       0       0       0       2       0
# 568       3       0          4       0       0       0       0       3
# 569       0       4          0       9      10       5       8       8
#
#      CS-107  HS-205/20  ...  CS-302  TC-383  MT-442  CS-306  CS-312  CS-406  \
# ...

# %%
#As there are multiple columns hence uing PCA method which combines high collinear columns
#Here reducing multidimensionilty of columns from 29 to 15 columns
from sklearn.decomposition import PCA
pca=PCA(n_components=15)
x=pca.fit_transform(x)
x.shape
# Out:
# (524, 15)

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x=pd.DataFrame(data=x)
x
# Out:
#             0         1         2         3         4         5         6   \
# 0    14.689696 -0.363964 -6.948836 -2.893510  2.318601  1.927440  1.810559
# 1    14.252243 -2.184170  0.678210  1.360187 -4.002044  4.656052  4.569760
# 2    -9.660071 -4.358192 -4.028651  3.107455  1.696039  0.653262 -2.151826
# 3    20.044723 -1.974118 -0.005710  3.453087 -1.522659 -4.373771 -3.315186
# 4    -6.400947 -5.104701 -3.335837  1.794698  0.776247  0.221418  2.830024
# ..         ...       ...       ...       ...       ...       ...       ...
# 519   6.675924  3.629827  2.968866  3.975857 -1.600883  0.366011  2.261085
# 520 -11.702920 -0.182463  0.613456 -0.209708 -2.164997 -0.349288 -2.713377
# 521 -13.275402 -0.277502  4.004405  0.288629 -1.044082 -6.394271 -0.800548
# 522  -8.578210  2.621572  3.144887  0.210528 -5.850398  1.169751 -1.508131
# 523  11.983950 -1.441240  7.633487 -2.663207 -1.983765 -2.253321  3.464017
#
# ...

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 564    2.607
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# Name: CGPA, Length: 524, dtype: float64

# %%
#As we observe that traget variable y has continous and unique data,the problem is considered as Regression problem

# %%
#Training the model

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import ExtraTreeRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor

# %%
#LR
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=45)

lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9799461877309713
# 0.061893735301431885
# 0.0064631630814680355

# %%
#lasso
ls=Lasso()
ls.fit(x_train,y_train)
ypred=ls.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9342828869968297
# 0.1126447865545459
# 0.021180033645708713

# %%
##Ridge
rd=Ridge()
rd.fit(x_train,y_train)
ypred=rd.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9799470952348522
# 0.06189240050840548
# 0.006462870601140577

# %%
##RFR
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
ypred=rfr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9699748397439466
# 0.07474303797468365
# 0.009676838731645586

# %%
##SVR
svr=SVR()
svr.fit(x_train,y_train)
ypred=svr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9632540584018521
# 0.08186720149330777
# 0.011842886028095523

# %%
##ETR
etr=ExtraTreeRegressor()
etr.fit(x_train,y_train)
ypred=etr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9366892805281029
# 0.11085443037974682
# 0.0204044746835443

# %%
##GBC
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
ypred=gbr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9760826599950131
# 0.06494239257181394
# 0.007708343274255522

# %%
##ABR
abr=AdaBoostRegressor()
abr.fit(x_train,y_train)
ypred=abr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.9684893980767266
# 0.0760547123616357
# 0.010155583202495029

# %%
##from above we observe that LinearRegression and Ridge model are giving best accuracy with minimum error
#lets check cross val score for the models and decide to choose the highest accuracy model performance

# %%
##lR
score=cross_val_score(lr,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.97998575 0.9844573  0.97306755 0.96852474 0.96603859]
# 0.9744147846477482
# Difference between accuracy and cross_val_score is -0.5925386571021596

# %%
##lasso
score=cross_val_score(ls,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.93146212 0.94895919 0.92916328 0.8994099  0.93012936]
# 0.9278247708359005
# Difference between accuracy and cross_val_score is 4.066462724082609

# %%
##Ridge
score=cross_val_score(rd,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.97998518 0.98445713 0.97306936 0.96852021 0.96604505]
# 0.9744153863655264
# Difference between accuracy and cross_val_score is -0.5925988288799755

# %%
##RFR
score=cross_val_score(rfr,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.960403   0.97759371 0.97424967 0.94905863 0.96756648]
# 0.9657742982278595
# Difference between accuracy and cross_val_score is 0.27150998488670863

# %%
##SVR
score=cross_val_score(svr,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.95303113 0.97299085 0.95274289 0.95428937 0.94762393]
# 0.9561356340007073
# Difference between accuracy and cross_val_score is 1.2353764076019291

# %%
##GBR
score=cross_val_score(gbr,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.973391   0.98274339 0.97568394 0.95733953 0.97012012]
# 0.9718555979492709
# Difference between accuracy and cross_val_score is -0.3366199872544273

# %%
##ABR
score=cross_val_score(abr,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.95244787 0.96686636 0.97055722 0.9475658  0.96506809]
# 0.9605010694780075
# Difference between accuracy and cross_val_score is 0.7988328598719119

# %%
##ETR
score=cross_val_score(etr,x,y,cv=5)
print(score)
print(score.mean())
print("Difference between accuracy and cross_val_score is",(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.90972473 0.93609906 0.94463827 0.89712694 0.93384966]
# 0.9242877308672716
# Difference between accuracy and cross_val_score is 4.420166720945506

# %%
#From above cross validation score ,we observe that RandomForestRegressor getting high accuracy with minimum difference between error values

# %%
#Hence choosing Random forest Regressor as final model

# %%
#Hyper parameter tuning for RFR
from sklearn.model_selection import GridSearchCV

parameters={'n_estimators': [25, 50, 100, 150], 
    'max_features': ['sqrt', 'log2'], 
    'max_depth': [3, 6, 9], 
    'max_leaf_nodes': [3, 6, 9]}

gcv=GridSearchCV(RandomForestRegressor(),parameters)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'max_depth': 9,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': 9,
#  'n_estimators': 25}

# %%
rfr=RandomForestRegressor(max_depth= 9,
 max_leaf_nodes= 9,
 n_estimators= 100)
rfr.fit(x_train,y_train)
ypred=rfr.predict(x_test)
acc=r2_score(y_test,ypred)
print(acc)
print(mean_absolute_error(y_test,ypred))
print(mean_squared_error(y_test,ypred))
# Out:
# 0.960052044625686
# 0.08883750874454012
# 0.012874866229507422

# %%
#Saving the best model
import joblib
joblib.dump(rfr,'Grades_prediction.pkl')
# Out:
# ['Grades_prediction.pkl']

# %%
#loading model
model=joblib.load('Grades_prediction.pkl')
model
# Out:
# RandomForestRegressor(max_depth=9, max_leaf_nodes=9)

# %%
df2=pd.DataFrame()
a=np.array(y_test)
prediction=model.predict(x_test)
df2['Actual values']=a
df2['predicted values']=prediction
df2
# Out:
#      Actual values  predicted values
# 0            2.343          2.498675
# 1            2.857          2.934774
# 2            2.576          2.809082
# 3            3.711          3.743568
# 4            2.384          2.495536
# ..             ...               ...
# 153          2.681          2.616213
# 154          2.512          2.614998
# 155          3.037          2.996441
# 156          2.602          2.622756
# 157          3.473          3.486401
#
# [158 rows x 2 columns]
