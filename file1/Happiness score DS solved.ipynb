# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#We observe that country and region have string values,other columns have int or float data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#We observe that no null value is present in Dataset

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#From above we observe that sum of null valuesis 0,as no null values are present in DataSet

# %%
df['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
duplicate=df.duplicated()
df[duplicate].sum()
# Out:
# Country                          0.0
# Region                           0.0
# Happiness Rank                   0.0
# Happiness Score                  0.0
# Standard Error                   0.0
# Economy (GDP per Capita)         0.0
# Family                           0.0
# Health (Life Expectancy)         0.0
# Freedom                          0.0
# Trust (Government Corruption)    0.0
# Generosity                       0.0
# Dystopia Residual                0.0
# dtype: float64

# %%
#We observe that no dupliacte values are present in the dataset

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#We observe from above that mean and median is almost equal in the columns,hence no skewness is present
#Also,we observe that no outliers are present in dataset as 75th qaurtile and max have almost equal values,there is no much deviation in values

# %%
for i in df:
    print(df[i].nunique())
# Out:
# 158
# 10
# 157
# 157
# 153
# 158
# 158
# 157
# 158
# 157
# 158
# 158

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#we observe that each data is unique in every column

# %%
for i in df:
    print(df[i].value_counts())
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# ...

# %%
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
#we observe that happiness score has more unique nad continuos values
#so,conwe consider its as Regresssion problem

# %% [markdown]
# EDA-UNIVARIATE ANALYSIS

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
#We observe that as GDP increases Happiness score increases,there is positive relation between them

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
#we observe that when corruption is less,the more is the happiness score of country

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <Axes: xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
#With increase in life expectancy ,the happiness score increases

# %%
y=df['Region'].value_counts().values
y
# Out:
# array([40, 29, 22, 21, 20,  9,  7,  6,  2,  2], dtype=int64)

# %%
df['Region'].value_counts().index
# Out:
# Index(['Sub-Saharan Africa', 'Central and Eastern Europe',
#        'Latin America and Caribbean', 'Western Europe',
#        'Middle East and Northern Africa', 'Southeastern Asia', 'Southern Asia',
#        'Eastern Asia', 'North America', 'Australia and New Zealand'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
labels=df['Region'].value_counts().index
colors = ['blue','purple','red','yellow','green']
y=df['Region'].value_counts().values
plt.pie(y,labels=labels,colors=colors,autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#From pie chart we notice that least happiness score is in sub_subarn Africa

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <Axes: xlabel='Family', ylabel='Happiness Score'>

# %%
#As there is incraesing in family,the happiness score increases

# %%
sns.regplot(x='Family',y='Happiness Score',data=df)
# Out:
# <Axes: xlabel='Family', ylabel='Happiness Score'>

# %%
sns.lmplot(x='Dystopia Residual',y='Happiness Score',data=df)

# %%
#We observe that dystopia behavior increses ,so does the happiness core increses,which is not a good thing

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <Axes: xlabel='Generosity', ylabel='Happiness Score'>

# %%
corr=df.corr()
corr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
corr['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#We observe that Health,family and economy are highly correlated to each other and to the target variable
#Standard error and generosity are less correlated
#while trust,dystopia and freedom are less correlated to each other and to target variable

# %%
sns.pairplot(df)

# %%
#we observe that diagonal plot is distribution plot,where almost for every feature data is normally distributed
#whlee standard error and trust have right skewed data

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
num=['Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']

# %%
plt.figure(figsize=(10,10))
p=1
for n in num:
    if p<=10:
        ax=plt.subplot(5,2,p)
        sns.boxplot(df[n])
        plt.xlabel(n)
    p+=1
plt.tight_layout()

# %%
#From above we observe that standard error and trust have outliers
#other features dont show outliers

# %%
from scipy.stats import zscore
out=df[['Happiness Rank',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']]
z=np.abs(zscore(out))
z
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)    Family  \
# 0          1.721000        0.805926                  1.369621  1.320281
# 1          1.699075        0.055889                  1.135226  1.514458
# 2          1.677149        0.854487                  1.192861  1.361054
# 3          1.655224        0.531526                  1.525130  1.251922
# 4          1.633299        0.722845                  1.194876  1.221204
# ..              ...             ...                       ...       ...
# 153        1.633576        0.774917                  1.552987  0.800520
# 154        1.655501        0.662582                  1.392303  2.346860
# 155        1.677427        0.132534                  0.455245  1.901086
# 156        1.699352        2.263962                  2.067566  2.118467
# 157        1.721277        1.134182                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 0     Switzerland      Western Europe               1            7.587
# 1         Iceland      Western Europe               2            7.561
# 2         Denmark      Western Europe               3            7.527
# 3          Norway      Western Europe               4            7.522
# 4          Canada       North America               5            7.427
# ..            ...                 ...             ...              ...
# 150   Ivory Coast  Sub-Saharan Africa             151            3.655
# 151  Burkina Faso  Sub-Saharan Africa             152            3.587
# 152   Afghanistan       Southern Asia             153            3.575
# 154         Benin  Sub-Saharan Africa             155            3.340
# 156       Burundi  Sub-Saharan Africa             157            2.905
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
df_new.shape
# Out:
# (149, 12)

# %%
df=df_new

# %%
#Checking for skewness in data
plt.figure(figsize=(10,10))
p=1
for i in num:
    if p<=10:
        plt.subplot(5,2,p)
        sns.distplot(df[i])
        plt.xlabel(i)
    p+=1
plt.tight_layout()

# %%
#we observe that almost data is normally skewed

# %%
#Seperating feaures and labels
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
#Applying label encoder for categroical columns

# %%
cat=['Country','Region']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat:
    df[i]=le.fit_transform(df[i].values.reshape(-1,1))
    
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        129       9               1            7.587         0.03411
# 1         57       9               2            7.561         0.04884
# 2         36       9               3            7.527         0.03328
# 3        101       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       65       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
#Applying standard scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0    1.278724  1.296837       -1.713905       -0.866786
# 1   -0.395242  1.296837       -1.691535        0.185669
# 2   -0.883482  1.296837       -1.669166       -0.926089
# 3    0.627737  1.296837       -1.646796       -0.531687
# 4   -1.162476 -0.026647       -1.624427       -0.765327
# ..        ...       ...             ...             ...
# 144 -0.209246  0.965966        1.641542        0.369294
# 145 -1.255474  0.965966        1.663911       -0.214450
# 146 -1.720465  0.635095        1.686281       -1.100427
# 147 -1.418221  0.965966        1.731020       -0.691734
# 148 -1.232225  0.965966        1.775759        2.882182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.381916  1.357879                  1.235390  1.583704
# 1                    1.138324  1.567882                  1.261541  1.338953
# ...

# %%
#Checking for MultiCollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor as vi
vif=pd.DataFrame()
vif['VIF values']=[vi(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns

# %%
vif
# Out:
#     VIF values                       Features
# 0     1.067348                        Country
# 1     1.482750                         Region
# 2    86.814181                 Happiness Rank
# 3     1.216933                 Standard Error
# 4    14.165329       Economy (GDP per Capita)
# 5     6.488064                         Family
# 6     9.075735       Health (Life Expectancy)
# 7     3.644836                        Freedom
# 8     1.996186  Trust (Government Corruption)
# 9     2.254527                     Generosity
# 10   20.169156              Dystopia Residual

# %%
#We observe that Happiness rank feature is highly collinear with other features
#hence,dropping that column
x.drop('Happiness Rank',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking VIF again for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor as vi
vif=pd.DataFrame()
vif['VIF values']=[vi(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns

# %%
vif
# Out:
#    VIF values                       Features
# 0    1.062453                        Country
# 1    1.420885                         Region
# 2    1.188082                 Standard Error
# 3    4.300757       Economy (GDP per Capita)
# 4    2.028894                         Family
# 5    3.982369       Health (Life Expectancy)
# 6    1.870357                        Freedom
# 7    1.498807  Trust (Government Corruption)
# 8    1.478136                     Generosity
# 9    1.036887              Dystopia Residual

# %%
corr['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#We observe that standard error is not considerable factor for predicting of happiness score,hence dropping that column
x.drop('Standard Error',axis=1,inplace=True)

# %%
x.shape
# Out:
# (149, 9)

# %%
x
# Out:
#       Country    Region  Economy (GDP per Capita)    Family  \
# 0    1.278724  1.296837                  1.381916  1.357879
# 1   -0.395242  1.296837                  1.138324  1.567882
# 2   -0.883482  1.296837                  1.198220  1.401974
# 3    0.627737  1.296837                  1.543526  1.283947
# 4   -1.162476 -0.026647                  1.200315  1.250726
# ..        ...       ...                       ...       ...
# 144 -0.209246  0.965966                 -1.026255 -0.945943
# 145 -1.255474  0.965966                 -1.562163 -0.624365
# 146 -1.720465  0.635095                 -1.402596 -2.811354
# 147 -1.418221  0.965966                 -1.488379 -2.608163
# 148 -1.232225  0.965966                 -2.190139 -2.361154
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.235390  1.583704                       2.472255
# 1                    1.261541  1.338953                       0.009247
# ...

# %%
y.shape
# Out:
# (149,)

# %%
y.value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.739    1
# 4.874    1
# 4.867    1
#         ..
# 5.889    1
# 5.878    1
# 5.855    1
# 5.848    1
# 2.905    1
# Name: Happiness Score, Length: 148, dtype: int64

# %%
#As we observe that there are less unique values and there is continous data in target variable
#Hence,it is Regression problem

# %% [markdown]
# MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
#LR model
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 7.478944834662561e-08
# 0.00023459572455312777
# 0.999999937338191

# %%
#Ridge
rd=Ridge()
rd.fit(x_train,y_train)
ypred=rd.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 6.427389145930835e-05
# 0.006611744567101358
# 0.999946148575784

# %%
##DTR
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
ypred=dtr.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 0.2448007777777777
# 0.36544444444444446
# 0.794895404133908

# %%
#SVR
svr=SVR()
svr.fit(x_train,y_train)
ypred=svr.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 0.0598445831406899
# 0.17822270580645044
# 0.9498596403521714

# %%
#RFC
rfc=RandomForestRegressor()
rfc.fit(x_train,y_train)
ypred=rfc.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 0.14531123520444464
# 0.2701991111111116
# 0.8782520119341068

# %%
#GBR
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
ypred=gbr.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 0.09694291048355884
# 0.2269054516646782
# 0.9187770698389586

# %%
##From above  we observe that r2 score of Gradient boosting Regressor is good,with less error
#One again checking the cross_val_score

# %%
#LR
score=cross_val_score(lr,x,y,cv=5)
print(score)
print(score.mean())
print('Difference between cross val score and r2 score is',(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.99999949 0.99999861 0.99999831 0.99999533 0.9999992 ]
# 0.9999981860424654
# Difference between cross val score and r2 score is -8.12211162035068

# %%
#Ridge
score=cross_val_score(rd,x,y,cv=5)
print(score)
print(score.mean())
print('Difference between cross val score and r2 score is',(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [0.99422927 0.99961725 0.99948295 0.9991568  0.9979057 ]
# 0.9980783944923651
# Difference between cross val score and r2 score is -7.930132465340655

# %%
#SVR
score=cross_val_score(svr,x,y,cv=5)
print(score)
print(score.mean())
print('Difference between cross val score and r2 score is',(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [-12.71852147   0.36079021   0.76361233  -0.47638552  -6.19475699]
# -3.653052287875577
# Difference between cross val score and r2 score is 457.1829357714536

# %%
#DTR
score=cross_val_score(dtr,x,y,cv=5)
print(score)
print(score.mean())
print('Difference between cross val score and r2 score is',(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [ -9.23911898 -11.32875645  -7.56243244 -10.49379812  -5.84180877]
# -8.893182951216117
# Difference between cross val score and r2 score is 981.1960021055075

# %%
#RFC
score=cross_val_score(rfc,x,y,cv=5)
print(score)
print(score.mean())
print('Difference between cross val score and r2 score is',(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [-8.45648376 -1.2855056  -0.88610477 -2.87458523 -6.13359136]
# -3.927254146171238
# Difference between cross val score and r2 score is 484.60312160101967

# %%
#GBR
score=cross_val_score(gbr,x,y,cv=5)
print(score)
print(score.mean())
print('Difference between cross val score and r2 score is',(r2_score(y_test,ypred)-score.mean())*100)
# Out:
# [-4.60719888 -0.22678522 -1.23329911 -2.75507913 -4.33392259]
# -2.631256986559314
# Difference between cross val score and r2 score is 355.00340563982724

# %%
#From above cross-val-score ,we observe that Ridge Regression providing good accuracy with less error

# %%
#Choosing Ridge as final model,for further hyperparametr tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'alpha': [0.1,0.001,0.0001,1,0],
    'solver':['auto',  'cholesky', 'lsqr',   'lbfgs']
}

gcv=GridSearchCV(rd,parameters,cv=5)
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 0.001, 0.0001, 1, 0],
#                          'solver': ['auto', 'cholesky', 'lsqr', 'lbfgs']})

# %%
gcv.best_params_
# Out:
# {'alpha': 0, 'solver': 'auto'}

# %%
gcv.score(x_train,y_train)
# Out:
# 0.9999999368541873

# %%
#Building model agin
rd=Ridge(alpha=0, solver='auto')
rd.fit(x_train,y_train)
ypred=rd.predict(x_test)
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(r2_score(y_test,ypred))
# Out:
# 7.478944834653349e-08
# 0.00023459572455303897
# 0.999999937338191

# %%
#Saving model 
import joblib
joblib.dump(rd,'Happiness_score_prediction.pkl')
# Out:
# ['Happiness_score_prediction.pkl']

# %%
model=joblib.load('Happiness_score_prediction.pkl')
predicted=model.predict(x_test)

# %%
a=np.array(y_test)
df2=pd.DataFrame()
df2['Actual values']=a
df2['predicted values']=predicted

# %%
df2
# Out:
#     Actual values  predicted values
# 0           5.286          5.286357
# 1           6.937          6.937304
# 2           4.512          4.512288
# 3           5.192          5.192323
# 4           5.212          5.212057
# 5           6.477          6.476761
# 6           5.605          5.604680
# 7           3.781          3.780797
# 8           5.474          5.473916
# 9           5.124          5.124189
# 10          4.642          4.642305
# 11          7.200          7.199766
# 12          6.298          6.298102
# 13          7.284          7.284072
# 14          6.901          6.901333
# 15          5.813          5.812596
# 16          3.904          3.903758
# 17          5.429          5.428651
# 18          5.824          5.824075
# 19          4.033          4.033100
# 20          6.505          6.505071
# 21          4.332          4.332231
# 22          6.670          6.669663
# 23          4.252          4.252063
# 24          4.218          4.218597
# ...
